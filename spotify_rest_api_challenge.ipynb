# %% [markdown]
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports
import pandas as pd 
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` a generate your __token__ access

# %%
# generate token with a POST request

client_id = 'c3e5d3adf180475bbc2fc05e0d451774'
client_secret = '7e4b9c9d27754e97b000e66efb781753'
auth_url = 'https://accounts.spotify.com/api/token'

auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()
access_token = auth_response['access_token']
access_token
# Out:
# 'BQA3JqX3Ossh5vjUHSkRmSUj-cmZbj9DZx8JOXeeLhZCbZe1dqQs6UzHmgiNo74bRgwllu1aO6JUaGgSBL8'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point) and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1'
resource = '/artists'
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)} #Diccionario de una sola key.
headers
# Out:
# {'Authorization': 'Bearer BQA3JqX3Ossh5vjUHSkRmSUj-cmZbj9DZx8JOXeeLhZCbZe1dqQs6UzHmgiNo74bRgwllu1aO6JUaGgSBL8'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp

# %%
artist = "/36QJpDe2go2KgaRleHCDTp"
type1 = "/related-artists"

response = requests.get(base_url+resource+artist+type1, headers=headers).json()
related_artists=pd.DataFrame(response["artists"])
related_artists
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/5...
# 1   {'spotify': 'https://open.spotify.com/artist/7...
# 2   {'spotify': 'https://open.spotify.com/artist/2...
# 3   {'spotify': 'https://open.spotify.com/artist/7...
# 4   {'spotify': 'https://open.spotify.com/artist/6...
# 5   {'spotify': 'https://open.spotify.com/artist/1...
# 6   {'spotify': 'https://open.spotify.com/artist/0...
# 7   {'spotify': 'https://open.spotify.com/artist/4...
# 8   {'spotify': 'https://open.spotify.com/artist/0...
# 9   {'spotify': 'https://open.spotify.com/artist/2...
# 10  {'spotify': 'https://open.spotify.com/artist/5...
# 11  {'spotify': 'https://open.spotify.com/artist/1...
# 12  {'spotify': 'https://open.spotify.com/artist/5...
# 13  {'spotify': 'https://open.spotify.com/artist/6...
# 14  {'spotify': 'https://open.spotify.com/artist/6...
# 15  {'spotify': 'https://open.spotify.com/artist/2...
# ...

# %%
artist = "/36QJpDe2go2KgaRleHCDTp"
type2 = "/top-tracks"
country = "?market=ES"

response = requests.get(base_url+resource+artist+type2+country, headers=headers).json()
top_tracks=pd.DataFrame(response["tracks"])
top_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
# your code
for i in related_artists["id"]:
    response = requests.get(base_url+resource+"/"+i+type2+country, headers=headers).json()
    top_tracks=pd.DataFrame(response["tracks"])
    print(top_tracks)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
top_artists_tracks = pd.DataFrame()
for i in related_artists["id"]:
    response = requests.get(base_url+resource+"/"+i+type2+country, headers=headers).json()
    top_tracks=pd.DataFrame(response["tracks"])
    top_artists_tracks=top_artists_tracks.append(top_tracks)

top_artists_tracks
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'album', 'artists': [{'external...
# ..                                                ...
# 5   {'album_type': 'album', 'artists': [{'external...
# 6   {'album_type': 'album', 'artists': [{'external...
# 7   {'album_type': 'album', 'artists': [{'external...
# 8   {'album_type': 'album', 'artists': [{'external...
# 9   {'album_type': 'album', 'artists': [{'external...
#
#                                               artists  disc_number  \
# 0   [{'external_urls': {'spotify': 'https://open.s...            1
# 1   [{'external_urls': {'spotify': 'https://open.s...            1
# 2   [{'external_urls': {'spotify': 'https://open.s...            1
# ...
